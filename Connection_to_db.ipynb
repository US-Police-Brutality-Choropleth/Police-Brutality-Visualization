# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

# %%
#store csv into df
csv_file = "cleaned_data/police_killings_2015.csv"
killings_df = pd.read_csv(csv_file, encoding="ISO-8859-1")
killings_df.head()
# Out:
#                  name age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington  16   Male            Black  February   23  2015
# 1      Aaron Rutledge  27   Male            White     April    2  2015
# 2         Aaron Siler  26   Male            White     March   14  2015
# 3        Aaron Valdez  25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic  29   Male            White     March   19  2015
#
#             streetaddress          city state  ...  p_income  h_income  \
# 0            Clearview Ln     Millbrook    AL  ...     28375   51367.0
# 1  300 block Iris Park Dr     Pineville    LA  ...     14678   27972.0
# 2    22nd Ave and 56th St       Kenosha    WI  ...     25286   45365.0
# 3       3000 Seminole Ave    South Gate    CA  ...     17194   48295.0
# 4          364 Hiwood Ave  Munroe Falls    OH  ...     33954   68785.0
#
#    county_income  comp_income  county_bucket  nat_bucket   pov     urate  \
# ...

# %%
killings_df['raceethnicity'].replace({'Hispanic/Latino':'Hispanic','Asian/Pacific Islander':'Asian'}, inplace=True)
killings_df['armed'].replace({'Firearm':'Yes','Non-lethal firearm':'Yes','Other':'Yes','Knife':'Yes','Vehicle':'Yes',
                             'Unknown':'Yes','Disputed':'Yes'},inplace=True)

# %%
killings_df.head()
# Out:
#                  name age gender raceethnicity     month  day  year  \
# 0  A'donte Washington  16   Male         Black  February   23  2015
# 1      Aaron Rutledge  27   Male         White     April    2  2015
# 2         Aaron Siler  26   Male         White     March   14  2015
# 3        Aaron Valdez  25   Male      Hispanic     March   11  2015
# 4        Adam Jovicic  29   Male         White     March   19  2015
#
#             streetaddress          city state  ...  p_income  h_income  \
# 0            Clearview Ln     Millbrook    AL  ...     28375   51367.0
# 1  300 block Iris Park Dr     Pineville    LA  ...     14678   27972.0
# 2    22nd Ave and 56th St       Kenosha    WI  ...     25286   45365.0
# 3       3000 Seminole Ave    South Gate    CA  ...     17194   48295.0
# 4          364 Hiwood Ave  Munroe Falls    OH  ...     33954   68785.0
#
#    county_income  comp_income  county_bucket  nat_bucket   pov     urate  \
# ...

# %%
engine = create_engine('sqlite:///killings_db.sqlite')
conn = engine.connect()

# %%
#check for tables
engine.table_names()
# Out:
# ['police_killings_2015', 'police_killings_2015_to_present']

# %%
#Use pandas to load csv converted DataFrame into database
killings_df.to_sql(name='police_killings_2015', con=engine, if_exists='replace', index=True)

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from police_killings_2015', con=engine).head()
# Out:
#    index                name age gender raceethnicity     month  day  year  \
# 0      0  A'donte Washington  16   Male         Black  February   23  2015
# 1      1      Aaron Rutledge  27   Male         White     April    2  2015
# 2      2         Aaron Siler  26   Male         White     March   14  2015
# 3      3        Aaron Valdez  25   Male      Hispanic     March   11  2015
# 4      4        Adam Jovicic  29   Male         White     March   19  2015
#
#             streetaddress          city  ... p_income  h_income  \
# 0            Clearview Ln     Millbrook  ...    28375   51367.0
# 1  300 block Iris Park Dr     Pineville  ...    14678   27972.0
# 2    22nd Ave and 56th St       Kenosha  ...    25286   45365.0
# 3       3000 Seminole Ave    South Gate  ...    17194   48295.0
# 4          364 Hiwood Ave  Munroe Falls  ...    33954   68785.0
#
#    county_income  comp_income  county_bucket  nat_bucket   pov     urate  \
# ...
