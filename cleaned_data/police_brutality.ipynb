# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.stats import linregress
import requests
import gmaps
import os
from ipywidgets.embed import embed_minimal_html
import scipy.stats as stats

# %%
#DATA IMPORT

#Reading the file from csv into pandas Dataframe
df = pd.read_csv('police_killings.csv', encoding="latin1")
df.head()
# Out:
#                  name age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington  16   Male            Black  February   23  2015
# 1      Aaron Rutledge  27   Male            White     April    2  2015
# 2         Aaron Siler  26   Male            White     March   14  2015
# 3        Aaron Valdez  25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic  29   Male            White     March   19  2015
#
#             streetaddress          city state  ...  share_hispanic  p_income  \
# 0            Clearview Ln     Millbrook    AL  ...             5.6     28375
# 1  300 block Iris Park Dr     Pineville    LA  ...             0.5     14678
# 2    22nd Ave and 56th St       Kenosha    WI  ...            16.8     25286
# 3       3000 Seminole Ave    South Gate    CA  ...            98.8     17194
# 4          364 Hiwood Ave  Munroe Falls    OH  ...             1.7     33954
#
#    h_income  county_income  comp_income  county_bucket  nat_bucket   pov  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'age', 'gender', 'raceethnicity', 'month', 'day', 'year',
#        'streetaddress', 'city', 'state', 'latitude', 'longitude', 'state_fp',
#        'county_fp', 'tract_ce', 'geo_id', 'county_id', 'namelsad',
#        'lawenforcementagency', 'cause', 'armed', 'pop', 'share_white',
#        'share_black', 'share_hispanic', 'p_income', 'h_income',
#        'county_income', 'comp_income', 'county_bucket', 'nat_bucket', 'pov',
#        'urate', 'college'],
#       dtype='object')

# %%
df_new = df.loc[:,["raceethnicity", "year", "city", "state", "latitude", "longitude", "state_fp", "armed"]]
df_new.head()
# Out:
#      raceethnicity  year          city state   latitude   longitude  state_fp  \
# 0            Black  2015     Millbrook    AL  32.529577  -86.362829         1
# 1            White  2015     Pineville    LA  31.321739  -92.434860        22
# 2            White  2015       Kenosha    WI  42.583560  -87.835710        55
# 3  Hispanic/Latino  2015    South Gate    CA  33.939298 -118.219463         6
# 4            White  2015  Munroe Falls    OH  41.148575  -81.429878        39
#
#      armed
# 0       No
# 1       No
# 2       No
# 3  Firearm
# 4       No

# %%
#DATA IMPORT

#Reading the file from csv into pandas Dataframe
df2 = pd.read_csv('police_killings_to_present.csv', encoding="latin1")
df2.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
df2.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
df2_new = df2.loc[:,["race", "date", "city", "state", "armed"]]
df2_new.head()
# Out:
#   race        date           city state       armed
# 0    A  2015-01-02        Shelton    WA         gun
# 1    W  2015-01-02          Aloha    OR         gun
# 2    H  2015-01-03        Wichita    KS     unarmed
# 3    W  2015-01-04  San Francisco    CA  toy weapon
# 4    H  2015-01-04          Evans    CO    nail gun

# %%
df2_new['date'] = pd.to_datetime(df2_new['date'])
df2_new['year'] = df2_new['date'].dt.year
df2_new.head()
# Out:
#   race       date           city state       armed  year
# 0    A 2015-01-02        Shelton    WA         gun  2015
# 1    W 2015-01-02          Aloha    OR         gun  2015
# 2    H 2015-01-03        Wichita    KS     unarmed  2015
# 3    W 2015-01-04  San Francisco    CA  toy weapon  2015
# 4    H 2015-01-04          Evans    CO    nail gun  2015
